# %%
import os
import pandas as pd

# %%
cwd = os.getcwd().split('amts')[0] + 'amts'
theme = "machine_learning"
pd.set_option('display.max_rows', 1000)

# %%
input_folder_path = rf"{cwd}/{theme}/data/inputs/CR_training_data"

# %%
input_file_path = rf"{input_folder_path}/loan_data_2007_2014.csv"
print(rf"Input File (Raw Data): {input_file_path}")
raw_input_df = pd.read_csv(input_file_path)
# Out:
# Input File (Raw Data): c:\dev\amts/machine_learning/data/inputs/CR_training_data/loan_data_2007_2014.csv
# C:\Users\FU689FU\AppData\Local\Temp\ipykernel_51720\2719992523.py:3: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_input_df = pd.read_csv(input_file_path)

# %%
# Always make a copy of the raw input data so that you don't overwrite the original data
prepped_input_df = raw_input_df.copy()
raw_input_df.head()
# Out:
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599       5000         5000           4975.0
# 1           1  1077430    1314167       2500         2500           2500.0
# 2           2  1077175    1313524       2400         2400           2400.0
# 3           3  1076863    1277178      10000        10000          10000.0
# 4           4  1075358    1311748       3000         3000           3000.0
#
#          term  int_rate  installment grade  ... total_bal_il il_util  \
# 0   36 months     10.65       162.87     B  ...          NaN     NaN
# 1   60 months     15.27        59.83     C  ...          NaN     NaN
# 2   36 months     15.96        84.33     C  ...          NaN     NaN
# 3   36 months     13.49       339.31     C  ...          NaN     NaN
# 4   60 months     12.69        67.79     B  ...          NaN     NaN
#
#   open_rv_12m open_rv_24m  max_bal_bc all_util total_rev_hi_lim inq_fi  \
# ...

# %%
print(raw_input_df.size)
# Out:
# 34971375

# %%
describe_df = raw_input_df.describe()
pivoted_descibed_data = pd.pivot_table(describe_df.reset_index(), columns='index')
pivoted_descibed_data
# Out:
# index                                 25%           50%           75%  \
# Unnamed: 0                   1.165710e+05  2.331420e+05  3.497130e+05
# acc_now_delinq               0.000000e+00  0.000000e+00  0.000000e+00
# all_util                              NaN           NaN           NaN
# annual_inc                   4.500000e+04  6.300000e+04  8.896000e+04
# annual_inc_joint                      NaN           NaN           NaN
# collection_recovery_fee      0.000000e+00  0.000000e+00  0.000000e+00
# collections_12_mths_ex_med   0.000000e+00  0.000000e+00  0.000000e+00
# delinq_2yrs                  0.000000e+00  0.000000e+00  0.000000e+00
# dti                          1.136000e+01  1.687000e+01  2.278000e+01
# dti_joint                             NaN           NaN           NaN
# funded_amnt                  8.000000e+03  1.200000e+04  2.000000e+04
# funded_amnt_inv              8.000000e+03  1.200000e+04  1.995000e+04
# ...
