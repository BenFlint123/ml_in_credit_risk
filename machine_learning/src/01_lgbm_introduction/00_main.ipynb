# %% [markdown]
# <!-- <h1>Main</h1>
# <p>We aim to compare the process of creating a PD model using a logistic regression and a common ML method (LGBM - Light Gradient Boosting Machine). </p>
# <p>To do so, this script aims to call and run all the steps, including preparing the data, building a logistic regression model and LGBM model, and finally comparing the performance between both models. </p> -->

# %% [markdown]
# <h2>1. Run Data Preparation</h2>

# %%
# %run ./01_data_preparation.ipynb
# Out:
# Input File (Raw Data): c:\dev\amts/machine_learning/data/inputs/01_lgbm_introduction/input_data.csv
#
# ---Start Data Preparation---
# WoE
# --Feature: days_past_due--
#   days_past_due_bin  days_past_due_woe       iv
# 0       (-inf, 1.5]          -0.579550  0.69811
# 1       (1.5, 15.5]          -0.040677  0.69811
# 2      (15.5, 30.5]           0.668674  0.69811
# 3      (30.5, 60.5]           2.172063  0.69811
# 4       (60.5, inf]           4.147649  0.69811
#
#
# --Feature: balance--
#          balance_bin  balance_woe       iv
# 0     (-inf, 138.68]     0.350854  0.13269
# 1  (138.68, 1121.69]     0.041654  0.13269
# 2     (1121.69, inf]    -1.035990  0.13269
#
#
# --Feature: credit_limit--
#    credit_limit_bin  credit_limit_woe        iv
# 0     (-inf, 250.0]          0.661028  0.344891
# 1   (250.0, 1150.0]          0.340847  0.344891
# 2  (1150.0, 1350.0]         -0.228108  0.344891
# 3  (1350.0, 1750.0]         -0.549483  0.344891
# ...

# %% [markdown]
# <h2>2. Run Logistic Regression Model Build</h2>

# %%
# %run ./02_logistic_regression_model_build.ipynb
# Out:
# Input File (Prepped Input Train Data): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/train_input_df.csv
# Input File (Prepped Input Test Data): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/test_input_df.csv
#
# ---Start Logistic Regression Model Build---
# --model 1--
# Optimization terminated successfully.
#          Current function value: 0.491629
#          Iterations 6
#                             Logit Regression Results
# ...
# Dep. Variable:     actual_default_flag   No. Observations:                 3325
# Model:                           Logit   Df Residuals:                     3320
# Method:                            MLE   Df Model:                            4
# Date:                 Wed, 04 Jun 2025   Pseudo R-squ.:                  0.2268
# Time:                         16:51:42   Log-Likelihood:                -1634.7
# converged:                        True   LL-Null:                       -2114.1
# ...

# %% [markdown]
# <h2>3. Run Light GBM Model Build</h2>

# %%
# %run ./03_light_gbm_model_build.ipynb
# Out:
# Input File (Prepped Input Train Data): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/train_input_df.csv
# Input File (Prepped Input Test Data): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/test_input_df.csv
#
# ---Start Light GBM Model Build---
# ---Base Light GBM---
# [LightGBM] [Info] Number of positive: 1105, number of negative: 2220
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.082481
# [LightGBM] [Debug] init for col-wise cost 0.000012 seconds, init for row-wise cost 0.001564 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002060 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 618
# [LightGBM] [Info] Number of data points in the train set: 3325, number of used features: 4
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.332331 -> initscore=-0.697662
# [LightGBM] [Info] Start training from score -0.697662
# ...

# %% [markdown]
# <h2>4. Run Model Performance Comparison</h2>

# %%
# %run ./04_model_performance_comparison.ipynb
# Out:
# Input File (Prepped Input Train Data): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/train_input_df.csv
# Input File (Prepped Input Test Data): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/test_input_df.csv
# Input File (Logistic Regression Model): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/logistic_regression_model.gz
# Input File (Base Light GBM Model): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/base_light_gbm_model.gz
# Input File (Force Overfit Light GBM Model): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/force_overfit_light_gbm_model.gz
# Input File (Optimised Light GBM Model): c:\dev\amts/machine_learning/data/outputs/01_lgbm_introduction/optimised_light_gbm_model.gz
#
# ---Start Model Performance Comparison---
#
# --Gini--
# --Actual vs Predicted Default Rate--
# --Scores Distribution--
# ...
